# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ***CHAN-VESE***

# %% [markdown]
# ***2 Vật thể đơn sắc***

# %%
df1= pd.read_csv(r'D:\Study\object-collision\plots\Chan-vese\chan-vese don sac 2 vat the.csv')
df1
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  0.645749
# 1             1      2  0.794749
# 2             2      3  0.762456
# 3             3      4  0.824496
# 4             4      5  0.801376
# ..          ...    ...       ...
# 145         145    146  0.637283
# 146         146    147  0.635786
# 147         147    148  0.654962
# 148         148    149  0.641463
# 149         149    150  0.634275
#
# [150 rows x 3 columns]

# %%
plt.plot(df1['Frame'], df1['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***3 Vật thể đơn sắc***

# %%
df2= pd.read_csv(r'D:\Study\object-collision\plots\Chan-vese\chan-vese don sac 3 vat the.csv')
df2
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  0.333943
# 1             1      2  0.315912
# 2             2      3  0.330904
# 3             3      4  0.392433
# 4             4      5  0.381349
# ..          ...    ...       ...
# 175         175    176  0.384715
# 176         176    177  0.385904
# 177         177    178  0.400047
# 178         178    179  0.356041
# 179         179    180  0.400230
#
# [180 rows x 3 columns]

# %%
plt.plot(df2['Frame'], df2['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***5 Vật thể đơn sắc***

# %%
df3 = pd.read_csv(r'D:\Study\object-collision\plots\Chan-vese\chan-vese don sac 5 vat the.csv')
df3
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  0.334646
# 1             1      2  0.302004
# 2             2      3  0.312271
# 3             3      4  0.319235
# 4             4      5  0.316760
# ..          ...    ...       ...
# 175         175    176  0.313425
# 176         176    177  0.325637
# 177         177    178  0.318485
# 178         178    179  0.324716
# 179         179    180  0.321024
#
# [180 rows x 3 columns]

# %%
plt.plot(df3['Frame'], df3['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***2 Vật thể có màu sắc***

# %%
df4 = pd.read_csv(r'D:\Study\object-collision\plots\Chan-vese\chan-vese co mau 2 vat the.csv')
df4
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  0.310192
# 1             1      2  0.308399
# 2             2      3  0.543097
# 3             3      4  0.307997
# 4             4      5  0.310683
# ..          ...    ...       ...
# 175         175    176  0.296281
# 176         176    177  0.300223
# 177         177    178  0.314859
# 178         178    179  0.297497
# 179         179    180  0.300853
#
# [180 rows x 3 columns]

# %%
plt.plot(df4['Frame'], df4['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***3 Vật thể có màu sắc***

# %%
df5 = pd.read_csv(r'D:\Study\object-collision\plots\Chan-vese\chan-vese co mau 3 vat the.csv')
df5
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  0.326377
# 1             1      2  0.319852
# 2             2      3  0.291606
# 3             3      4  0.309024
# 4             4      5  0.302157
# ..          ...    ...       ...
# 175         175    176  0.340052
# 176         176    177  0.298573
# 177         177    178  0.297407
# 178         178    179  0.298506
# 179         179    180  0.299714
#
# [180 rows x 3 columns]

# %%
plt.plot(df5['Frame'], df5['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***5 Vật thể có màu sắc***

# %%
df6 = pd.read_csv(r'D:\Study\object-collision\plots\Chan-vese\chan-vese co mau 5 vat the.csv')
df6
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  0.302574
# 1             1      2  0.284670
# 2             2      3  0.314840
# 3             3      4  0.292797
# 4             4      5  0.304226
# ..          ...    ...       ...
# 175         175    176  0.318253
# 176         176    177  0.308573
# 177         177    178  0.302921
# 178         178    179  0.320569
# 179         179    180  0.302318
#
# [180 rows x 3 columns]

# %%
plt.plot(df6['Frame'], df6['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***Tỉ lệ thời gian khi tăng số lượng vật thể - Đơn sắc***

# %%
# tính theo công thức Time n vật thể - time m vật thể / n - m
print('2 vật thể đơn sắc với 3 vật thể đơn sắc', (df2['Time'].mean() - df1['Time'].mean())/1)
print('2 vật thể đơn sắc với 5 vật thể đơn sắc', (df3['Time'].mean() - df1['Time'].mean())/3)
print('3 vật thể đơn sắc với 5 vật thể đơn sắc', (df2['Time'].mean() - df3['Time'].mean())/2)
# Out:
# 2 vật thể đơn sắc với 3 vật thể đơn sắc -0.3586300858466999
# 2 vật thể đơn sắc với 5 vật thể đơn sắc -0.12050046622482619
# 3 vật thể đơn sắc với 5 vật thể đơn sắc 0.001435656413889319

# %% [markdown]
# ***Tỉ lệ thời gian khi tăng số lượng vật thể - Có màu sắc***

# %%
# tính theo công thức Time n vật thể - time m vật thể / n - m
print('2 vật thể có màu với 3 vật thể có màu', (df5['Time'].mean() - df4['Time'].mean())/1)
print('2 vật thể có màu với 5 vật thể có màu', (df6['Time'].mean() - df4['Time'].mean())/3)
print('3 vật thể có màu với 5 vật thể có màu', (df6['Time'].mean() - df5['Time'].mean())/2)
# Out:
# 2 vật thể có màu với 3 vật thể có màu 0.0015471570277718616
# 2 vật thể có màu với 5 vật thể có màu 0.003250743894431307
# 3 vật thể có màu với 5 vật thể có màu 0.00410253732776103
