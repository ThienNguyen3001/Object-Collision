# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ***CHAN-VESE***

# %% [markdown]
# ***2 Vật thể đơn sắc***

# %%
df1= pd.read_csv(r'D:\Study\object-collision\plots\Chan-vese\2 ball_monochromatic_Chan-vese.csv')
df1
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  1.497399
# 1             1      2  1.150313
# 2             2      3  1.339774
# 3             3      4  2.053375
# 4             4      5  2.597244
# ..          ...    ...       ...
# 145         145    146  0.792741
# 146         146    147  0.819844
# 147         147    148  1.038101
# 148         148    149  1.016740
# 149         149    150  1.030609
#
# [150 rows x 3 columns]

# %%
plt.plot(df1['Frame'], df1['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***3 Vật thể đơn sắc***

# %%
df2= pd.read_csv(r'D:\Study\object-collision\plots\Chan-vese\3 ball_monochromatic_Chan-vese.csv')
df2
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  0.379819
# 1             1      2  0.367665
# 2             2      3  0.380294
# 3             3      4  0.357275
# 4             4      5  0.389983
# ..          ...    ...       ...
# 175         175    176  0.344873
# 176         176    177  0.373813
# 177         177    178  0.345918
# 178         178    179  0.367481
# 179         179    180  0.353167
#
# [180 rows x 3 columns]

# %%
plt.plot(df2['Frame'], df2['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***5 Vật thể đơn sắc***

# %%
df3 = pd.read_csv(r'D:\Study\object-collision\plots\Chan-vese\5 ball_monochromatic_Chan-vese.csv')
df3
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  0.515165
# 1             1      2  0.559187
# 2             2      3  0.515990
# 3             3      4  0.501140
# 4             4      5  0.515619
# ..          ...    ...       ...
# 175         175    176  0.473923
# 176         176    177  0.518274
# 177         177    178  0.455445
# 178         178    179  0.386220
# 179         179    180  0.360087
#
# [180 rows x 3 columns]

# %%
plt.plot(df3['Frame'], df3['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***2 Vật thể có màu sắc***

# %%
df4 = pd.read_csv(r'D:\Study\object-collision\plots\Chan-vese\2 ball_polychromatic_Chan-vese.csv')
df4
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  0.476036
# 1             1      2  0.363992
# 2             2      3  0.379382
# 3             3      4  0.352016
# 4             4      5  0.375318
# ..          ...    ...       ...
# 175         175    176  0.484682
# 176         176    177  0.516871
# 177         177    178  0.472322
# 178         178    179  0.488291
# 179         179    180  0.354042
#
# [180 rows x 3 columns]

# %%
plt.plot(df4['Frame'], df4['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***3 Vật thể có màu sắc***

# %%
df5 = pd.read_csv(r'D:\Study\object-collision\plots\Chan-vese\3 ball_polychromatic_Chan-vese.csv')
df5
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  0.351527
# 1             1      2  0.364332
# 2             2      3  0.361233
# 3             3      4  0.356868
# 4             4      5  0.356646
# ..          ...    ...       ...
# 175         175    176  0.366397
# 176         176    177  0.344682
# 177         177    178  0.365500
# 178         178    179  0.342176
# 179         179    180  0.362804
#
# [180 rows x 3 columns]

# %%
plt.plot(df5['Frame'], df5['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***5 Vật thể có màu sắc***

# %%
df6 = pd.read_csv(r'D:\Study\object-collision\plots\Chan-vese\5 ball_polychromatic_Chan-vese.csv')
df6
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  0.360813
# 1             1      2  0.390356
# 2             2      3  0.382255
# 3             3      4  0.388727
# 4             4      5  0.370024
# ..          ...    ...       ...
# 175         175    176  0.375042
# 176         176    177  0.357748
# 177         177    178  0.354173
# 178         178    179  0.364091
# 179         179    180  0.355725
#
# [180 rows x 3 columns]

# %%
plt.plot(df6['Frame'], df6['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***Tỉ lệ thời gian khi tăng số lượng vật thể - Đơn sắc***

# %%
# tính theo công thức Time n vật thể - time m vật thể / n - m
print('2 vật thể đơn sắc với 3 vật thể đơn sắc', (df2['Time'].mean() - df1['Time'].mean())/1)
print('2 vật thể đơn sắc với 5 vật thể đơn sắc', (df3['Time'].mean() - df1['Time'].mean())/3)
print('3 vật thể đơn sắc với 5 vật thể đơn sắc', (df2['Time'].mean() - df3['Time'].mean())/2)
# Out:
# 2 vật thể đơn sắc với 3 vật thể đơn sắc -0.4983288286566618
# 2 vật thể đơn sắc với 5 vật thể đơn sắc -0.15932192909481582
# 3 vật thể đơn sắc với 5 vật thể đơn sắc -0.010181520686107143

# %% [markdown]
# ***Tỉ lệ thời gian khi tăng số lượng vật thể - Có màu sắc***

# %%
# tính theo công thức Time n vật thể - time m vật thể / n - m
print('2 vật thể có màu với 3 vật thể có màu', (df5['Time'].mean() - df4['Time'].mean())/1)
print('2 vật thể có màu với 5 vật thể có màu', (df6['Time'].mean() - df4['Time'].mean())/3)
print('3 vật thể có màu với 5 vật thể có màu', (df6['Time'].mean() - df5['Time'].mean())/2)
# Out:
# 2 vật thể có màu với 3 vật thể có màu -0.00023874652777922112
# 2 vật thể có màu với 5 vật thể có màu 0.0011346198648127432
# 3 vật thể có màu với 5 vật thể có màu 0.0018213030611087255
