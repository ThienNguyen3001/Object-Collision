# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1= pd.read_csv(r'C:\Users\Admin\Desktop\python\object-collision\plots\chan-vese video 3 vat the .csv')
df1
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  0.487842
# 1             1      2  0.936830
# 2             2      3  0.787794
# 3             3      4  0.386732
# 4             4      5  0.400189
# ..          ...    ...       ...
# 241         241    242  0.307743
# 242         242    243  0.336796
# 243         243    244  0.343593
# 244         244    245  0.403353
# 245         245    246  0.391114
#
# [246 rows x 3 columns]

# %%
plt.plot(df1['Frame'], df1['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %%
df2= pd.read_csv(r'C:\Users\Admin\Desktop\python\object-collision\plots\chan-vese video don sac 2 vat the.csv')
df2
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  0.623571
# 1             1      2  0.581951
# 2             2      3  0.555009
# 3             3      4  0.587689
# 4             4      5  0.639419
# ..          ...    ...       ...
# 145         145    146  0.591502
# 146         146    147  0.578223
# 147         147    148  0.591831
# 148         148    149  0.602480
# 149         149    150  0.593698
#
# [150 rows x 3 columns]

# %%
plt.plot(df2['Frame'], df2['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %%
df3 = pd.read_csv(r'C:\Users\Admin\Desktop\python\object-collision\plots\watershed video 3 vat the .csv')
df3
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  2.935382
# 1             1      2  3.115883
# 2             2      3  2.637141
# 3             3      4  3.787316
# 4             4      5  3.579975
# ..          ...    ...       ...
# 241         241    242  2.660712
# 242         242    243  2.613502
# 243         243    244  2.589003
# 244         244    245  3.991118
# 245         245    246  2.541100
#
# [246 rows x 3 columns]

# %%
plt.plot(df3['Frame'], df3['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %%
df4 = pd.read_csv(r'C:\Users\Admin\Desktop\python\object-collision\plots\watershed video don sac 2 vat the.csv')
df4
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  3.873298
# 1             1      2  2.707829
# 2             2      3  1.000604
# 3             3      4  1.003691
# 4             4      5  1.176670
# ..          ...    ...       ...
# 145         145    146  0.021293
# 146         146    147  0.021512
# 147         147    148  0.018040
# 148         148    149  0.022285
# 149         149    150  0.022466
#
# [150 rows x 3 columns]

# %%
plt.plot(df4['Frame'], df4['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()
