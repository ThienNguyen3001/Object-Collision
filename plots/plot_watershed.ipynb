# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ***WATERSHED - ACTIVE CONTOUR MODEL***

# %% [markdown]
# ***2 Vật thể đơn sắc***

# %%
df1= pd.read_csv(r'D:\Study\object-collision\plots\Watershed-ACM\don sac 2 vat the.csv')
df1
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  4.014876
# 1             1      2  2.629385
# 2             2      3  1.085330
# 3             3      4  1.091300
# 4             4      5  1.167437
# ..          ...    ...       ...
# 145         145    146  0.013490
# 146         146    147  0.013073
# 147         147    148  0.013366
# 148         148    149  0.013887
# 149         149    150  0.013153
#
# [150 rows x 3 columns]

# %%
plt.plot(df1['Frame'], df1['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***3 Vật thể đơn sắc***

# %%
df2= pd.read_csv(r'D:\Study\object-collision\plots\Watershed-ACM\don sac 3 vat the.csv')
df2
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  2.321847
# 1             1      2  2.776416
# 2             2      3  3.346412
# 3             3      4  2.080173
# 4             4      5  2.259641
# ..          ...    ...       ...
# 175         175    176  3.245369
# 176         176    177  2.318384
# 177         177    178  2.195645
# 178         178    179  2.187417
# 179         179    180  2.158478
#
# [180 rows x 3 columns]

# %%
plt.plot(df2['Frame'], df2['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***5 Vật thể đơn sắc***

# %%
df3 = pd.read_csv(r'D:\Study\object-collision\plots\Watershed-ACM\don sac 5 vat the.csv')
df3
# Out:
#      Unnamed: 0  Frame       Time
# 0             0      1   4.358131
# 1             1      2   3.790697
# 2             2      3   5.337380
# 3             3      4   3.622340
# 4             4      5   5.167442
# ..          ...    ...        ...
# 175         175    176  12.309412
# 176         176    177   7.066950
# 177         177    178   8.098937
# 178         178    179   6.295380
# 179         179    180   8.070530
#
# [180 rows x 3 columns]

# %%
plt.plot(df3['Frame'], df3['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***2 Vật thể có màu sắc***

# %%
df4 = pd.read_csv(r'D:\Study\object-collision\plots\Watershed-ACM\co mau 2 vat the.csv')
df4
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  1.730514
# 1             1      2  1.468602
# 2             2      3  1.595346
# 3             3      4  1.344292
# 4             4      5  1.926319
# ..          ...    ...       ...
# 175         175    176  1.108426
# 176         176    177  1.418556
# 177         177    178  1.242689
# 178         178    179  0.928447
# 179         179    180  1.041349
#
# [180 rows x 3 columns]

# %%
plt.plot(df4['Frame'], df4['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***3 Vật thể có màu sắc***

# %%
df5 = pd.read_csv(r'D:\Study\object-collision\plots\Watershed-ACM\co mau 3 vat the.csv')
df5
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  3.129234
# 1             1      2  3.221000
# 2             2      3  5.203128
# 3             3      4  2.523045
# 4             4      5  2.487363
# ..          ...    ...       ...
# 175         175    176  3.562846
# 176         176    177  2.644935
# 177         177    178  2.166053
# 178         178    179  2.619711
# 179         179    180  3.096229
#
# [180 rows x 3 columns]

# %%
plt.plot(df5['Frame'], df5['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***5 Vật thể có màu sắc***

# %%
df6 = pd.read_csv(r'D:\Study\object-collision\plots\Watershed-ACM\co mau 5 vat the.csv')
df6
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  5.967007
# 1             1      2  5.370124
# 2             2      3  6.537244
# 3             3      4  5.426666
# 4             4      5  6.354703
# ..          ...    ...       ...
# 175         175    176  8.305710
# 176         176    177  6.621826
# 177         177    178  7.946053
# 178         178    179  6.627640
# 179         179    180  7.986449
#
# [180 rows x 3 columns]

# %%
plt.plot(df6['Frame'], df6['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***Tỉ lệ thời gian khi tăng số lượng vật thể - Đơn sắc***

# %%
# tính theo công thức Time n vật thể - time m vật thể / n - m
print('2 vật thể đơn sắc với 3 vật thể đơn sắc', (df2['Time'].mean() - df1['Time'].mean())/1)
print('2 vật thể đơn sắc với 5 vật thể đơn sắc', (df3['Time'].mean() - df1['Time'].mean())/3)
print('3 vật thể đơn sắc với 5 vật thể đơn sắc', (df2['Time'].mean() - df3['Time'].mean())/2)
# Out:
# 2 vật thể đơn sắc với 3 vật thể đơn sắc 1.3246799423188858
# 2 vật thể đơn sắc với 5 vật thể đơn sắc 1.675742892663699
# 3 vật thể đơn sắc với 5 vật thể đơn sắc -1.8512743678361059

# %% [markdown]
# ***Tỉ lệ thời gian khi tăng số lượng vật thể - Có màu sắc***

# %%
# tính theo công thức Time n vật thể - time m vật thể / n - m
print('2 vật thể có màu với 3 vật thể có màu', (df5['Time'].mean() - df4['Time'].mean())/1)
print('2 vật thể có màu với 5 vật thể có màu', (df6['Time'].mean() - df4['Time'].mean())/3)
print('3 vật thể có màu với 5 vật thể có màu', (df6['Time'].mean() - df5['Time'].mean())/2)
# Out:
# 2 vật thể có màu với 3 vật thể có màu 1.4458179584721924
# 2 vật thể có màu với 5 vật thể có màu 1.6424699204611122
# 3 vật thể có màu với 5 vật thể có màu 1.740795901455572
