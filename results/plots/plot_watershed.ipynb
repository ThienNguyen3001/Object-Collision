# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ***WATERSHED - ACTIVE CONTOUR MODEL***

# %% [markdown]
# ***2 Vật thể đơn sắc***

# %%
df1= pd.read_csv(r'D:\Study\object-collision\plots\Watershed-ACM\2 ball_monochromatic_Watershed_ACM.csv')
df1
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  4.399787
# 1             1      2  3.897094
# 2             2      3  1.589522
# 3             3      4  1.945306
# 4             4      5  1.625385
# ..          ...    ...       ...
# 145         145    146  0.013614
# 146         146    147  0.013719
# 147         147    148  0.014486
# 148         148    149  0.013957
# 149         149    150  0.013241
#
# [150 rows x 3 columns]

# %%
plt.plot(df1['Frame'], df1['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***3 Vật thể đơn sắc***

# %%
df2= pd.read_csv(r'D:\Study\object-collision\plots\Watershed-ACM\3 ball_monochromatic_Watershed_ACM.csv')
df2
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  2.435230
# 1             1      2  2.451900
# 2             2      3  2.118587
# 3             3      4  2.107458
# 4             4      5  3.591553
# ..          ...    ...       ...
# 175         175    176  2.017030
# 176         176    177  1.959524
# 177         177    178  3.054041
# 178         178    179  2.784884
# 179         179    180  2.117436
#
# [180 rows x 3 columns]

# %%
plt.plot(df2['Frame'], df2['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***5 Vật thể đơn sắc***

# %%
df3 = pd.read_csv(r'D:\Study\object-collision\plots\Watershed-ACM\5 ball_monochromatic_Watershed_ACM.csv')
df3
# Out:
#      Unnamed: 0  Frame       Time
# 0             0      1   7.202715
# 1             1      2   4.276864
# 2             2      3   4.071360
# 3             3      4   5.912175
# 4             4      5   5.829014
# ..          ...    ...        ...
# 175         175    176  15.454790
# 176         176    177   8.187016
# 177         177    178   9.166200
# 178         178    179   8.929610
# 179         179    180   7.827352
#
# [180 rows x 3 columns]

# %%
plt.plot(df3['Frame'], df3['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***2 Vật thể có màu sắc***

# %%
df4 = pd.read_csv(r'D:\Study\object-collision\plots\Watershed-ACM\2 ball_polychromatic_Watershed_ACM.csv')
df4
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  3.525857
# 1             1      2  1.692305
# 2             2      3  1.761987
# 3             3      4  1.210126
# 4             4      5  1.127196
# ..          ...    ...       ...
# 175         175    176  1.205290
# 176         176    177  1.559652
# 177         177    178  1.506266
# 178         178    179  1.054605
# 179         179    180  1.189900
#
# [180 rows x 3 columns]

# %%
plt.plot(df4['Frame'], df4['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***3 Vật thể có màu sắc***

# %%
df5 = pd.read_csv(r'D:\Study\object-collision\plots\Watershed-ACM\3 ball_polychromatic_Watershed_ACM.csv')
df5
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  3.051873
# 1             1      2  3.540446
# 2             2      3  4.331402
# 3             3      4  2.463910
# 4             4      5  2.443572
# ..          ...    ...       ...
# 175         175    176  2.294567
# 176         176    177  2.436754
# 177         177    178  2.279262
# 178         178    179  3.685910
# 179         179    180  2.592298
#
# [180 rows x 3 columns]

# %%
plt.plot(df5['Frame'], df5['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***5 Vật thể có màu sắc***

# %%
df6 = pd.read_csv(r'D:\Study\object-collision\plots\Watershed-ACM\5 ball_polychromatic_Watershed_ACM.csv')
df6
# Out:
#      Unnamed: 0  Frame      Time
# 0             0      1  6.829916
# 1             1      2  6.119525
# 2             2      3  7.137463
# 3             3      4  8.366687
# 4             4      5  9.493088
# ..          ...    ...       ...
# 175         175    176  8.553219
# 176         176    177  9.324795
# 177         177    178  9.221146
# 178         178    179  7.866123
# 179         179    180  9.049110
#
# [180 rows x 3 columns]

# %%
plt.plot(df6['Frame'], df6['Time'])
plt.xlabel('Frame')
plt.ylabel('Time')
plt.show()

# %% [markdown]
# ***Tỉ lệ thời gian khi tăng số lượng vật thể - Đơn sắc***

# %%
# tính theo công thức Time n vật thể - time m vật thể / n - m
print('2 vật thể đơn sắc với 3 vật thể đơn sắc', (df2['Time'].mean() - df1['Time'].mean())/1)
print('2 vật thể đơn sắc với 5 vật thể đơn sắc', (df3['Time'].mean() - df1['Time'].mean())/3)
print('3 vật thể đơn sắc với 5 vật thể đơn sắc', (df2['Time'].mean() - df3['Time'].mean())/2)
# Out:
# 2 vật thể đơn sắc với 3 vật thể đơn sắc 1.1664827440533296
# 2 vật thể đơn sắc với 5 vật thể đơn sắc 2.2087711447955556
# 3 vật thể đơn sắc với 5 vật thể đơn sắc -2.7299153451666687

# %% [markdown]
# ***Tỉ lệ thời gian khi tăng số lượng vật thể - Có màu sắc***

# %%
# tính theo công thức Time n vật thể - time m vật thể / n - m
print('2 vật thể có màu với 3 vật thể có màu', (df5['Time'].mean() - df4['Time'].mean())/1)
print('2 vật thể có màu với 5 vật thể có màu', (df6['Time'].mean() - df4['Time'].mean())/3)
print('3 vật thể có màu với 5 vật thể có màu', (df6['Time'].mean() - df5['Time'].mean())/2)
# Out:
# 2 vật thể có màu với 3 vật thể có màu 1.233966286716664
# 2 vật thể có màu với 5 vật thể có màu 2.384143509479638
# 3 vật thể có màu với 5 vật thể có màu 2.9592321208611247
